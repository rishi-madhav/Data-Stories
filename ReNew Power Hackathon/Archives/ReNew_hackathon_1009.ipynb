# %% [markdown]
# **READING THE DATASET**

# %%
# LOAD THE LIBRARIES
import pandas as pd
import numpy as np
import pandas_profiling as pp
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid') # darkgrid, white grid, dark, white and ticks

# Importing all necessary libraries

from math import sqrt
import xgboost as xgb
import lightgbm as lgb
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from functools import partial
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from bayes_opt import BayesianOptimization
from sklearn.linear_model import Ridge, Lasso

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.model_selection import cross_val_score, KFold
from pprint import pprint

# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# %%
train = pd.read_csv('./ReNew_Participants_Data/train.csv')
test = pd.read_csv('./ReNew_Participants_Data/test.csv')

print("The Wind Turbine training dataset has", train.shape[0], "records, each with",train.shape[1],"attributes.")
print("The Wind Turbine test dataset has", test.shape[0], "records, each with",test.shape[1],"attributes.")

train.head()
# Out:
# The Wind Turbine training dataset has 909604 records, each with 16 attributes.
# The Wind Turbine test dataset has 303202 records, each with 14 attributes.
#              timestamp  active_power_calculated_by_converter  \
# 0  2021-02-19 20:18:00                            816.636759
# 1  2021-04-27 04:55:00                            419.107829
# 2  2021-01-25 06:26:00                           1303.530558
# 3  2021-10-30 03:47:00                             61.494872
# 4  2021-03-15 00:39:00                            593.514364
#
#    active_power_raw  ambient_temperature  generator_speed  \
# 0        834.917206            31.694380      1159.616602
# 1        421.050873            12.894948       928.747996
# 2       1337.566142            16.648388      1201.219775
# 3         53.481008            28.388141       769.806122
# 4        611.659108            31.519527      1046.916768
#
#    generator_winding_temp_max  grid_power10min_average  nc1_inside_temp  \
# 0                   65.954214               917.897085        31.881972
# 1                   59.571319               445.554250        32.423705
# 2                   61.270498              1364.716003        11.446849
# 3                   40.674348                14.324897        34.253204
# 4                   64.341763               599.020172        32.405586
#
#    nacelle_temp  reactice_power_calculated_by_converter  reactive_power  \
# 0     31.504713                              141.457644      165.501518
# 1     32.755770                               89.186457      113.835236
# 2     18.332985                              230.622309      281.452253
# 3     32.662889                               66.211015       75.017531
# 4     31.466387                              137.163938      160.202421
#
#    wind_direction_raw  wind_speed_raw  wind_speed_turbulence   turbine_id  \
# 0          280.864782        7.057000               0.544082  Turbine_108
# 1          299.552460        5.474937               0.469031   Turbine_18
# 2           84.960106        8.092457               0.622318  Turbine_105
# 3           87.261119        4.071032               0.760719   Turbine_15
# 4          313.724818        6.357943               0.346068   Turbine_01
#
#       Target
# 0  47.582787
# 1  46.070328
# 2  39.989236
# 3  46.056587
# 4  54.346095

# %%
test.head()
# Out:
#    active_power_calculated_by_converter  active_power_raw  \
# 0                             15.507537         19.956882
# 1                            472.577255        478.373881
# 2                            447.829615        451.158264
# 3                            254.014336        249.438965
# 4                           1174.930566       1202.654077
#
#    ambient_temperature  generator_speed  generator_winding_temp_max  \
# 0            40.233264       410.538834                   57.357366
# 1            12.306687       965.077563                   51.796728
# 2            29.106771       948.035899                   60.493098
# 3            27.074900       804.963776                   55.741899
# 4            32.148434      1199.754858                   67.272313
#
#    grid_power10min_average  nc1_inside_temp  nacelle_temp  \
# 0                84.008399        48.826597     45.363477
# 1               492.531362        27.457511     24.045565
# 2               393.151576        39.410553     35.715697
# 3               178.715101        29.476841     31.151895
# 4              1115.850317        31.920549     30.864276
#
#    reactice_power_calculated_by_converter  reactive_power  wind_direction_raw  \
# 0                                2.419202        1.468876          156.399396
# 1                               96.152070      119.378235           56.443802
# 2                               90.251529      117.192635          224.540263
# 3                               89.273838      105.086257          182.151426
# 4                              189.731988      236.053320          261.672180
#
#    wind_speed_raw  wind_speed_turbulence   turbine_id
# 0        2.438629               0.790435   Turbine_14
# 1        5.900371               0.544198   Turbine_19
# 2        5.924923               0.513481   Turbine_14
# 3        4.409707               0.448881  Turbine_120
# 4        7.822326               0.561465  Turbine_158

# %%
# Drop the timestamp column
train.drop(['timestamp'],axis=1,inplace=True)
#test.drop('turbine_id', axis=1, inplace=True)

# %%
# Check for null
train.isnull().sum()
# Out:
# active_power_calculated_by_converter      0
# active_power_raw                          0
# ambient_temperature                       0
# generator_speed                           0
# generator_winding_temp_max                0
# grid_power10min_average                   0
# nc1_inside_temp                           0
# nacelle_temp                              0
# reactice_power_calculated_by_converter    0
# reactive_power                            0
# wind_direction_raw                        0
# wind_speed_raw                            0
# wind_speed_turbulence                     0
# turbine_id                                0
# Target                                    0
# dtype: int64

# %% [markdown]
# There are no NULL values to deal with.

# %%
#Creating a Numerical dataframe and omitting Timestamp column
train_num = train.select_dtypes(["float64"])
train_cat = train.select_dtypes(["object"])
train_num.head()
# Out:
#    active_power_calculated_by_converter  active_power_raw  \
# 0                            816.636759        834.917206
# 1                            419.107829        421.050873
# 2                           1303.530558       1337.566142
# 3                             61.494872         53.481008
# 4                            593.514364        611.659108
#
#    ambient_temperature  generator_speed  generator_winding_temp_max  \
# 0            31.694380      1159.616602                   65.954214
# 1            12.894948       928.747996                   59.571319
# 2            16.648388      1201.219775                   61.270498
# 3            28.388141       769.806122                   40.674348
# 4            31.519527      1046.916768                   64.341763
#
#    grid_power10min_average  nc1_inside_temp  nacelle_temp  \
# 0               917.897085        31.881972     31.504713
# 1               445.554250        32.423705     32.755770
# 2              1364.716003        11.446849     18.332985
# 3                14.324897        34.253204     32.662889
# 4               599.020172        32.405586     31.466387
#
#    reactice_power_calculated_by_converter  reactive_power  wind_direction_raw  \
# 0                              141.457644      165.501518          280.864782
# 1                               89.186457      113.835236          299.552460
# 2                              230.622309      281.452253           84.960106
# 3                               66.211015       75.017531           87.261119
# 4                              137.163938      160.202421          313.724818
#
#    wind_speed_raw  wind_speed_turbulence     Target
# 0        7.057000               0.544082  47.582787
# 1        5.474937               0.469031  46.070328
# 2        8.092457               0.622318  39.989236
# 3        4.071032               0.760719  46.056587
# 4        6.357943               0.346068  54.346095

# %%
train_num.hist(figsize = (15, 15))
plt.tight_layout()
plt.show()

# %%
train_cat.head()
# Out:
#     turbine_id
# 0  Turbine_108
# 1   Turbine_18
# 2  Turbine_105
# 3   Turbine_15
# 4   Turbine_01

# %%
print("******************************************************************************************************************************************************")
#print("Barplot for ",train_cat.turbine_id)
plt.figure(figsize = (16, 8))
sns.barplot(x = train_cat["turbine_id"].value_counts().index.tolist(),y = train_cat["turbine_id"].value_counts().values.tolist())
plt.tight_layout()
plt.show()
print("******************************************************************************************************************************************************")
# Out:
# ******************************************************************************************************************************************************
# ******************************************************************************************************************************************************

# %%
train_num.skew(axis=0)
# Out:
# active_power_calculated_by_converter      1.094894
# active_power_raw                          1.079560
# ambient_temperature                      -0.405606
# generator_speed                          -0.432870
# generator_winding_temp_max                0.482791
# grid_power10min_average                   1.008062
# nc1_inside_temp                           0.040530
# nacelle_temp                             -0.427542
# reactice_power_calculated_by_converter    1.731298
# reactive_power                            1.638332
# wind_direction_raw                       -0.363971
# wind_speed_raw                            0.718327
# wind_speed_turbulence                     2.205472
# Target                                    0.705359
# dtype: float64

# %% [markdown]
# **DATA VISUALIZATION**

# %%
# Plotting the distributions of the numerical features
plt.figure(figsize=(20,16))

for i, col in enumerate(list(train_num)):
    plt.subplot(4,5,i+1)
    sns.distplot(train_num[col], color='g', kde=True, label='data')
    plt.grid()
    plt.tight_layout()

# %% [markdown]
# **Inference**
#
# 1. **Target, nacelle_temp, generator_wind_temp_max** - normally distributed. Hence no need to scale.
#
# 2. **active_power_calculated_by_converter, active_power_raw, grid_power10min_average , wind_speed_raw, wind_speed_turbulence** are **skewed**, - need to scale.
#
# 3. **ambient_temperature , generator_speed, reactice_power_calculated_by_converter, reactive_power, wind_direction_raw** distributions are bi-model. We will scale and check how they look.

# %%
log_feature = ['active_power_calculated_by_converter', 'active_power_raw',
       'ambient_temperature', 'generator_speed', 'generator_winding_temp_max',
       'grid_power10min_average', 'nc1_inside_temp', 'nacelle_temp',
       'reactice_power_calculated_by_converter', 'reactive_power',
       'wind_direction_raw', 'wind_speed_raw', 'wind_speed_turbulence']

# %%
for x in log_feature:
    train_num[x] = train_num[x].apply(lambda t : 0.000001 if t <= 0 else t)
    train_num[x] = np.log(train_num[x])
    test[x] = test[x].apply(lambda t : 0.000001 if t <= 0 else t)
    test[x] = np.log(test[x])

# %%
train_num.head()
# Out:
#    active_power_calculated_by_converter  active_power_raw  \
# 0                              6.705194          6.727333
# 1                              6.038128          6.042754
# 2                              7.172832          7.198607
# 3                              4.118954          3.979327
# 4                              6.386061          6.416175
#
#    ambient_temperature  generator_speed  generator_winding_temp_max  \
# 0             3.456139         7.055845                    4.188961
# 1             2.556836         6.833837                    4.087174
# 2             2.812313         7.091093                    4.115298
# 3             3.345971         6.646139                    3.705598
# 4             3.450607         6.953605                    4.164209
#
#    grid_power10min_average  nc1_inside_temp  nacelle_temp  \
# 0                 6.822085         3.462041      3.450137
# 1                 6.099319         3.478890      3.489079
# 2                 7.218702         2.437714      2.908702
# 3                 2.661999         3.533780      3.486240
# 4                 6.395295         3.478331      3.448920
#
#    reactice_power_calculated_by_converter  reactive_power  wind_direction_raw  \
# 0                                4.952000        5.108980            5.637873
# 1                                4.490729        4.734752            5.702290
# 2                                5.440781        5.639963            4.442182
# 3                                4.192847        4.317722            4.468905
# 4                                4.921177        5.076438            5.748516
#
#    wind_speed_raw  wind_speed_turbulence     Target
# 0        1.954020              -0.608656  47.582787
# 1        1.700181              -0.757086  46.070328
# 2        2.090932              -0.474304  39.989236
# 3        1.403897              -0.273491  46.056587
# 4        1.849705              -1.061119  54.346095

# %%
# For One Encoding for Training Date Sets
from sklearn.preprocessing import LabelEncoder

# Label Encoding the categorical columns
le = LabelEncoder()

# Encode turbine_id in train dataset
le.fit(train_cat.turbine_id)
train_cat.turbine_id = le.transform(train_cat.turbine_id)

# Encode turbine_id in test dataset
le.fit(test.turbine_id)
test.turbine_id = le.transform(test.turbine_id)

# %%
train = pd.concat([train_num, train_cat], axis=1)
train.head()
# Out:
#    active_power_calculated_by_converter  active_power_raw  \
# 0                              6.705194          6.727333
# 1                              6.038128          6.042754
# 2                              7.172832          7.198607
# 3                              4.118954          3.979327
# 4                              6.386061          6.416175
#
#    ambient_temperature  generator_speed  generator_winding_temp_max  \
# 0             3.456139         7.055845                    4.188961
# 1             2.556836         6.833837                    4.087174
# 2             2.812313         7.091093                    4.115298
# 3             3.345971         6.646139                    3.705598
# 4             3.450607         6.953605                    4.164209
#
#    grid_power10min_average  nc1_inside_temp  nacelle_temp  \
# 0                 6.822085         3.462041      3.450137
# 1                 6.099319         3.478890      3.489079
# 2                 7.218702         2.437714      2.908702
# 3                 2.661999         3.533780      3.486240
# 4                 6.395295         3.478331      3.448920
#
#    reactice_power_calculated_by_converter  reactive_power  wind_direction_raw  \
# 0                                4.952000        5.108980            5.637873
# 1                                4.490729        4.734752            5.702290
# 2                                5.440781        5.639963            4.442182
# 3                                4.192847        4.317722            4.468905
# 4                                4.921177        5.076438            5.748516
#
#    wind_speed_raw  wind_speed_turbulence     Target  turbine_id
# 0        1.954020              -0.608656  47.582787           4
# 1        1.700181              -0.757086  46.070328          12
# 2        2.090932              -0.474304  39.989236           3
# 3        1.403897              -0.273491  46.056587          10
# 4        1.849705              -1.061119  54.346095           0

# %%
# Plotting the distributions of the numerical features
plt.figure(figsize=(20,16))

for i, col in enumerate(list(train)):
    plt.subplot(4,5,i+1)
    sns.distplot(train[col], color='g', kde=True, label='data')
    plt.grid()
    plt.tight_layout()

# %% [markdown]
# # **SCALING FEATURES**

# %%
# Scaling the Data Sets 
from sklearn.preprocessing import StandardScaler

scale_features = ['active_power_calculated_by_converter', 'active_power_raw','ambient_temperature', 'generator_speed', 'generator_winding_temp_max',
                   'grid_power10min_average', 'nc1_inside_temp', 'nacelle_temp','reactice_power_calculated_by_converter', 'reactive_power',
                   'wind_direction_raw', 'wind_speed_raw', 'wind_speed_turbulence']
scale = StandardScaler()
for fs in scale_features:
    train[fs] = scale.fit_transform(train[[fs]])
    test[fs] = scale.fit_transform(test[[fs]])

# %%
train.skew(axis=0)
# Out:
# active_power_calculated_by_converter      -2.070053
# active_power_raw                          -1.189463
# ambient_temperature                       -0.811184
# generator_speed                          -16.908310
# generator_winding_temp_max                -0.229396
# grid_power10min_average                   -1.745006
# nc1_inside_temp                           -1.372696
# nacelle_temp                              -1.078643
# reactice_power_calculated_by_converter    -5.645137
# reactive_power                           -12.513448
# wind_direction_raw                        -1.490540
# wind_speed_raw                            -0.241306
# wind_speed_turbulence                     -0.541470
# Target                                     0.705359
# turbine_id                                -0.005678
# dtype: float64

# %%
# Plotting the distributions of the numerical features after applying log transformation and scaling
plt.figure(figsize=(20,16))

for i, col in enumerate(list(train)):
    plt.subplot(4,5,i+1)
    sns.distplot(train[col], color='b', kde=True, label='data')
    plt.grid()
    plt.tight_layout()

# %% [markdown]
# # **FEATURE SELECTION**

# %%
X = train.drop('Target', axis=1)
y = train['Target']

# %%
X.shape[1]
# Out:
# 14

# %%
X.head()
# Out:
#    active_power_calculated_by_converter  active_power_raw  \
# 0                              0.713967          0.775973
# 1                              0.267439          0.248789
# 2                              1.026999          1.138895
# 3                             -1.017238         -1.340225
# 4                              0.500342          0.536356
#
#    ambient_temperature  generator_speed  generator_winding_temp_max  \
# 0             0.750813         0.546957                    0.592831
# 1            -1.707336         0.084568                   -0.040229
# 2            -1.009015         0.620371                    0.134689
# 3             0.449681        -0.306365                   -2.413439
# 4             0.735692         0.334015                    0.438887
#
#    grid_power10min_average  nc1_inside_temp  nacelle_temp  \
# 0                 0.766860         0.092507      0.008158
# 1                 0.329486         0.221244      0.337520
# 2                 1.006868        -7.733947     -4.571166
# 3                -1.750572         0.640638      0.313503
# 4                 0.508592         0.216973     -0.002137
#
#    reactice_power_calculated_by_converter  reactive_power  wind_direction_raw  \
# 0                                0.340740        0.293846            0.688164
# 1                                0.158568        0.159423            0.762524
# 2                                0.533776        0.484575           -0.692104
# 3                                0.040925        0.009626           -0.661256
# 4                                0.328566        0.282157            0.815886
#
#    wind_speed_raw  wind_speed_turbulence  turbine_id
# 0        0.694710              -0.175622           4
# 1       -0.051841              -0.504645          12
# 2        1.097374               0.122194           3
# 3       -0.923224               0.567334          10
# 4        0.387915              -1.178592           0

# %% [markdown]
# **Correlation check for multi-collinearity**

# %%
# Plotting a heatmap plot

from turtle import color
plt.figure(figsize=(25,12))
p = sns.heatmap(data=X.corr(method='pearson'), cmap='RdYlGn', annot=True, center=0)

# %% [markdown]
# **Correlation of Independent Variables**
#
# Based on the coefficient values some of the independent variables are highly correlated to each other (value >=0.8). This means we may need to drop one of these to ensure we do not overfit the model. We will analyze further with some other methods (VIF, Feature Selection and Embedded methods) to come to an optimal set of features.
#
# * active_power_calculated_by_converter & active_power_raw
# * active_power_calculated_by_converter & wind_speed_raw
# * active_power_calculated_by_converter & grid_power10min_average
# * active_power_raw & wind_speed_raw
# * active_power_raw & grid_power10min_average
# * generator_speed & active_power_calculated_by_converter
# * reactice_power_calculated_by_converter & reactive_power

# %%
X.corrwith(y)
# Out:
# active_power_calculated_by_converter     -0.044264
# active_power_raw                         -0.040752
# ambient_temperature                       0.401813
# generator_speed                          -0.027191
# generator_winding_temp_max                0.301815
# grid_power10min_average                  -0.050655
# nc1_inside_temp                           0.205364
# nacelle_temp                              0.509125
# reactice_power_calculated_by_converter   -0.036458
# reactive_power                           -0.024747
# wind_direction_raw                        0.073833
# wind_speed_raw                           -0.072810
# wind_speed_turbulence                     0.080449
# turbine_id                               -0.138806
# dtype: float64

# %% [markdown]
# **VIF Check**

# %%
# Import VIF library for multi-collinearity check
from statsmodels.stats.outliers_influence import variance_inflation_factor 

def calc_vif(dataframe):

    # calculating VIF
    vif = pd.DataFrame()
    vif["Variables"] = dataframe.columns
    vif["VIF"] = [variance_inflation_factor(dataframe.values, i) for i in range(dataframe.shape[1])]
    vif = vif.sort_values(ascending=False, by="VIF")
    return(vif)

calc_vif(X)
# Out:
#                                  Variables       VIF
# 0     active_power_calculated_by_converter  7.473784
# 1                         active_power_raw  7.144378
# 11                          wind_speed_raw  5.571424
# 5                  grid_power10min_average  4.733177
# 7                             nacelle_temp  3.065796
# 8   reactice_power_calculated_by_converter  2.634672
# 4               generator_winding_temp_max  2.568588
# 6                          nc1_inside_temp  2.177188
# 9                           reactive_power  2.145109
# 3                          generator_speed  1.822694
# 12                   wind_speed_turbulence  1.430978
# 2                      ambient_temperature  1.160889
# 10                      wind_direction_raw  1.047152
# 13                              turbine_id  1.019604

# %% [markdown]
# * VIF starts at 1 and has no upper limit
# * VIF = 1, no correlation between the independent variable and the other variables
# * VIF exceeding 5 or 10 indicates high multicollinearity between this independent variable and the others

# %% [markdown]
# **Wrapper Methods**
#
# * Sequential Feature Selector - Forward Selection
# * Backward Elimination - Recursive Feature Elimination (RFE)
# * Stepwise Selection: Bi-directional with a combination of Forward Selection & Backward Elimination

# %% [markdown]
# **Forward Selection Method - SFS() from Mlxtend**

# %%
# Sequential Feature Selection (SFS)
sfs = SFS(LinearRegression(), forward=True, floating=False, scoring='r2', cv=5, k_features='best')
sfs.fit(X, y)
fig = plot_sfs(sfs.get_metric_dict(), kind='std_err')

plt.title('Sequential Forward Selection (w. StdErr)')
plt.grid()
plt.show()

# %% [markdown]
# **SelectKBest with Pearson's f_regression**

# %%
best_features = SelectKBest(score_func=f_regression, k='all')
fit = best_features.fit(X,y)

feat_scores = pd.DataFrame({'Feature': X.columns, 'Pearsons Score' : fit.scores_})
print(feat_scores.sort_values(by=['Pearsons Score'], ascending=False))
# Out:
#                                    Feature  Pearsons Score
# 7                             nacelle_temp   318276.891616
# 2                      ambient_temperature   175134.720688
# 4               generator_winding_temp_max    91161.727741
# 6                          nc1_inside_temp    40050.969787
# 13                              turbine_id    17869.709894
# 12                   wind_speed_turbulence     5925.334239
# 10                      wind_direction_raw     4985.705951
# 11                          wind_speed_raw     4847.834573
# 5                  grid_power10min_average     2339.974133
# 0     active_power_calculated_by_converter     1785.647883
# 1                         active_power_raw     1513.075870
# 8   reactice_power_calculated_by_converter     1210.630686
# 3                          generator_speed      673.008545
# 9                           reactive_power      557.392202

# %%
Kbest_features = feat_scores.nlargest(7, 'Pearsons Score')
print(Kbest_features)
# Out:
#                        Feature  Pearsons Score
# 7                 nacelle_temp   318276.891616
# 2          ambient_temperature   175134.720688
# 4   generator_winding_temp_max    91161.727741
# 6              nc1_inside_temp    40050.969787
# 13                  turbine_id    17869.709894
# 12       wind_speed_turbulence     5925.334239
# 10          wind_direction_raw     4985.705951

# %% [markdown]
# **Backward Elimination: Recursive Forward Elimination Method RFE() from Sklearn**

# %%
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
np.random.seed(123)
#names = pd.DataFrame(X.columns)
model = LinearRegression()

#Define RFE 
rfe = RFE(model, step=1) 
my_values = rfe.fit(X,y)

#Create a dataframe for the results
df_RFE_results = []
for i in range(X.shape[1]):
    df_RFE_results.append(
        {
            'Feature' : X.columns[i],
            'Selected' : my_values.support_[i],
            'RFE_Ranking' : my_values.ranking_[i]
        }
    )

df_RFE_results = pd.DataFrame(df_RFE_results)
df_RFE_results.index.name = 'Columns'
df_RFE_results
# Out:
#                                         Feature  Selected  RFE_Ranking
# Columns
# 0          active_power_calculated_by_converter     False            2
# 1                              active_power_raw     False            5
# 2                           ambient_temperature      True            1
# 3                               generator_speed     False            6
# 4                    generator_winding_temp_max      True            1
# 5                       grid_power10min_average      True            1
# 6                               nc1_inside_temp      True            1
# 7                                  nacelle_temp      True            1
# 8        reactice_power_calculated_by_converter     False            7
# 9                                reactive_power     False            4
# 10                           wind_direction_raw     False            8
# 11                               wind_speed_raw      True            1
# 12                        wind_speed_turbulence      True            1
# 13                                   turbine_id     False            3

# %%
RFE_features = df_RFE_results[df_RFE_results['RFE_Ranking'] == 1]
print(RFE_features)
# Out:
#                             Feature  Selected  RFE_Ranking
# Columns
# 2               ambient_temperature      True            1
# 4        generator_winding_temp_max      True            1
# 5           grid_power10min_average      True            1
# 6                   nc1_inside_temp      True            1
# 7                      nacelle_temp      True            1
# 11                   wind_speed_raw      True            1
# 12            wind_speed_turbulence      True            1

# %%
feat_list = {'SelectKBest' : Kbest_features['Feature'],
            'RFE Linear' : RFE_features['Feature']
            }
key_features = pd.DataFrame(feat_list)
key_features = key_features.apply(lambda x: pd.Series(x.dropna().values))
key_features
# Out:
#                   SelectKBest                  RFE Linear
# 0         ambient_temperature         ambient_temperature
# 1  generator_winding_temp_max  generator_winding_temp_max
# 2             nc1_inside_temp     grid_power10min_average
# 3                nacelle_temp             nc1_inside_temp
# 4          wind_direction_raw                nacelle_temp
# 5       wind_speed_turbulence              wind_speed_raw
# 6                  turbine_id       wind_speed_turbulence

# %% [markdown]
# # Train Test Split

# %%
# SPLIT TRAIN DATASET INTO TRAIN & VALIDATION TO TEST MODEL BEFORE PREDICTING ON TEST DATASET

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, random_state=42)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (818643, 14) (818643,) (90961, 14) (90961,)

# %% [markdown]
# # **BUILDING A BASE MODEL**

# %%
test.head()
# Out:
#    active_power_calculated_by_converter  active_power_raw  \
# 0                             -0.358164         -0.845516
# 1                              0.168609          0.192505
# 2                              0.162899          0.178816
# 3                              0.099447          0.032449
# 4                              0.258382          0.392340
#
#    ambient_temperature  generator_speed  generator_winding_temp_max  \
# 0             1.284113        -0.284848                   -0.258544
# 1            -1.889565         0.059108                   -0.904580
# 2             0.531272         0.052386                    0.072237
# 3             0.353109        -0.010172                   -0.437882
# 4             0.769846         0.139859                    0.719692
#
#    grid_power10min_average  nc1_inside_temp  nacelle_temp  \
# 0                 0.029225         3.062313      2.897717
# 1                 0.201000        -1.015945     -2.313470
# 2                 0.182062         1.619690      1.044187
# 3                 0.109681        -0.476413     -0.072102
# 4                 0.264371         0.115795     -0.149438
#
#    reactice_power_calculated_by_converter  reactive_power  wind_direction_raw  \
# 0                               -0.395739       -0.689105            0.097655
# 1                                0.208913        0.213674           -0.922848
# 2                                0.203772        0.212288            0.410800
# 3                                0.202880        0.203995            0.232288
# 4                                0.259997        0.261404            0.537062
#
#    wind_speed_raw  wind_speed_turbulence  turbine_id
# 0       -2.515149              -0.369523           9
# 1        0.222668              -0.369523          13
# 2        0.231956              -0.369523           9
# 3       -0.489671              -0.369523           5
# 4        0.808729              -0.369523          11

# %% [markdown]
# **LINEAR REGRESSION**

# %%
# %%time
# Fit a simple Linear Regression
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
lr_pred = lr_model.predict(X_test)

lr_train_acc = (lr_model.score(X_train, y_train))*100
lr_val_acc = (lr_model.score(X_test, y_test))*100
mape_lr = mean_absolute_percentage_error(y_test, lr_pred)

print(f"Training accuracy: {lr_train_acc} %")
print(f"Validation accuracy: {lr_val_acc} %")
print(f"Linear Regression Mean Absolute Percent Error: {mape_lr}")
# Out:
# Training accuracy: 41.07612103176081 %
# Validation accuracy: 41.25479496159502 %
# Linear Regression Mean Absolute Percent Error: 0.029449920272629302
# CPU times: user 555 ms, sys: 244 ms, total: 799 ms
# Wall time: 351 ms

# %% [markdown]
# **RANDOM FOREST REGRESSION**

# %%
# %%time
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)

rf_train_acc = (rf_model.score(X_train, y_train))*100
rf_val_acc = (rf_model.score(X_test, y_test))*100
mape_rf = mean_absolute_percentage_error(y_test, rf_pred)

print(f"Training accuracy: {rf_train_acc} %")
print(f"Validation accuracy: {rf_val_acc} %")
print(f"Random Forest Model Mean Absolute Percent Error: {mape_rf}")
# Out:
# Training accuracy: 97.73690522250025 %
# Validation accuracy: 83.65371381742143 %
# Random Forest Model Mean Absolute Percent Error: 0.01364082318821077
# CPU times: user 21min 58s, sys: 16 s, total: 22min 13s
# Wall time: 22min 49s

# %%
pd.DataFrame(rf_model.feature_importances_, index=X.columns, columns=['Score']).sort_values('Score', ascending=False)
# Out:
#                                            Score
# nacelle_temp                            0.230230
# ambient_temperature                     0.227826
# turbine_id                              0.146581
# generator_winding_temp_max              0.086741
# nc1_inside_temp                         0.068430
# wind_direction_raw                      0.068282
# wind_speed_turbulence                   0.035266
# reactice_power_calculated_by_converter  0.034834
# grid_power10min_average                 0.034652
# wind_speed_raw                          0.015483
# active_power_raw                        0.013752
# reactive_power                          0.013495
# active_power_calculated_by_converter    0.012821
# generator_speed                         0.011607

# %%
pd.DataFrame(rf_model.feature_importances_, index=X.columns, columns=['Score']).sort_values('Score', ascending=False).plot(kind = 'bar', figsize=(20,7))
plt.show()

# %% [markdown]
# **LIGHTGBM REGRESSION**

# %%
# %%time
lgb_model = LGBMRegressor(n_estimators=1000)
lgb_model.fit(X_train, y_train)
lgb_pred = lgb_model.predict(X_test)

lgb_train_acc = (lgb_model.score(X_train, y_train))*100
lgb_val_acc = (lgb_model.score(X_test, y_test))*100
mape_lgb = mean_absolute_percentage_error(y_test, lgb_pred)

print(f"Training accuracy: {lgb_train_acc} %")
print(f"Validation accuracy: {lgb_val_acc} %")
print(f"CatBoost Model Mean Absolute Percent Error: {mape_lgb}")
# Out:
# Training accuracy: 80.79760021252225 %
# Validation accuracy: 78.60351821970204 %
# CatBoost Model Mean Absolute Percent Error: 0.017744843216291013
# CPU times: user 2min 6s, sys: 7.5 s, total: 2min 13s
# Wall time: 19.3 s

# %% [markdown]
# **LASSO & RIDGE REGRESSION**

# %%
# %%time
# Initiate a ridge object and fit to the training data
ridge = Ridge(alpha=0.1, fit_intercept=True, normalize=True)
ridge.fit(X_train, y_train)
rg_pred = ridge.predict(X_test)

rg_train_acc = ridge.score(X_train, y_train)*100
rg_val_acc = ridge.score(X_test, y_test)*100
mape_rg = mean_absolute_percentage_error(y_test, rg_pred)

print(f"Training accuracy: {rg_train_acc} %")
print(f"Validation accuracy: {rg_val_acc} %")
print(f"Ridge Mean Absolute Percent Error: {mape_rg}")
# Out:
# Training accuracy: 40.58431496048646 %
# Validation accuracy: 40.74718074140933 %
# Ridge Mean Absolute Percent Error: 0.029602108915351075
# CPU times: user 582 ms, sys: 425 ms, total: 1.01 s
# Wall time: 438 ms

# %%
# %%time
# Initiate a Lasso object and fit to the training data
lasso = Lasso(random_state=1)
lasso.fit(X_train, y_train)
ls_pred = lasso.predict(X_test)

ls_train_acc = lasso.score(X_train, y_train)*100
ls_val_acc = lasso.score(X_test, y_test)*100
mape_ls = mean_absolute_percentage_error(y_test, ls_pred)

print(f"Training accuracy: {ls_train_acc} %")
print(f"Validation accuracy: {ls_val_acc} %")
print(f"Lasso Mean Absolute Percent Error: {mape_ls}")
# Out:
# Training accuracy: 13.006682770881305 %
# Validation accuracy: 12.956586996778373 %
# Lasso Mean Absolute Percent Error: 0.03775677653789301
# CPU times: user 392 ms, sys: 207 ms, total: 599 ms
# Wall time: 234 ms

# %% [markdown]
# **XGB REGRESSION**

# %%
# %%time
# XG Boost Regressor
XGB_model = XGBRegressor(booster='gbtree', n_estimators=200, max_depth=12, random_state=42)
XGB_model.fit(X_train, y_train)
XGB_pred = XGB_model.predict(X_test)

xg_train_acc = (XGB_model.score(X_train, y_train))*100
xg_val_acc = (XGB_model.score(X_test, y_test))*100
mape_xg = mean_absolute_percentage_error(y_test, XGB_pred)

print(f"Training accuracy: {xg_train_acc} %")
print(f"Validation accuracy: {xg_val_acc} %")
print(f"XGBoost Model Mean Absolute Percent Error: {mape_xg}")
# Out:
# Training accuracy: 92.48724142328794 %
# Validation accuracy: 81.75842378005318 %
# XGBoost Model Mean Absolute Percent Error: 0.01593811418456402
# CPU times: user 27min 24s, sys: 1min 15s, total: 28min 40s
# Wall time: 3min 55s

# %% [markdown]
# **CATBOOST REGRESSOR**

# %%
# %%time
from catboost import CatBoostRegressor, cv

cat_model = CatBoostRegressor(iterations=200, learning_rate=0.7, loss_function='MAPE', random_state=42)
cat_model.fit(X_train, y_train)
cat_pred = cat_model.predict(X_test)

cat_train_acc = (cat_model.score(X_train, y_train))*100
cat_val_acc = (cat_model.score(X_test, y_test))*100
mape_cat = mean_absolute_percentage_error(y_test, cat_pred)

print(f"Training accuracy: {cat_train_acc} %")
print(f"Validation accuracy: {cat_val_acc} %")
print(f"CatBoost Model Mean Absolute Percent Error: {mape_cat}")
# Out:
# 0:	learn: 0.0342630	total: 176ms	remaining: 35s
# 1:	learn: 0.0308886	total: 239ms	remaining: 23.6s
# 2:	learn: 0.0287443	total: 320ms	remaining: 21s
# 3:	learn: 0.0273558	total: 382ms	remaining: 18.7s
# 4:	learn: 0.0264805	total: 505ms	remaining: 19.7s
# 5:	learn: 0.0258108	total: 615ms	remaining: 19.9s
# 6:	learn: 0.0253876	total: 688ms	remaining: 19s
# 7:	learn: 0.0250266	total: 748ms	remaining: 18s
# 8:	learn: 0.0246891	total: 805ms	remaining: 17.1s
# 9:	learn: 0.0244394	total: 891ms	remaining: 16.9s
# 10:	learn: 0.0241147	total: 963ms	remaining: 16.5s
# 11:	learn: 0.0239400	total: 1.03s	remaining: 16.2s
# 12:	learn: 0.0237835	total: 1.1s	remaining: 15.8s
# 13:	learn: 0.0236634	total: 1.15s	remaining: 15.3s
# 14:	learn: 0.0235286	total: 1.22s	remaining: 15s
# 15:	learn: 0.0233277	total: 1.28s	remaining: 14.7s
# 16:	learn: 0.0232365	total: 1.34s	remaining: 14.5s
# 17:	learn: 0.0231617	total: 1.4s	remaining: 14.2s
# 18:	learn: 0.0230459	total: 1.46s	remaining: 13.9s
# 19:	learn: 0.0229899	total: 1.52s	remaining: 13.7s
# 20:	learn: 0.0228959	total: 1.57s	remaining: 13.4s
# 21:	learn: 0.0228405	total: 1.63s	remaining: 13.2s
# 22:	learn: 0.0227663	total: 1.69s	remaining: 13s
# 23:	learn: 0.0226747	total: 1.75s	remaining: 12.8s
# 24:	learn: 0.0226142	total: 1.8s	remaining: 12.6s
# 25:	learn: 0.0225741	total: 1.86s	remaining: 12.5s
# 26:	learn: 0.0224687	total: 1.92s	remaining: 12.3s
# 27:	learn: 0.0224136	total: 1.97s	remaining: 12.1s
# 28:	learn: 0.0223718	total: 2.02s	remaining: 11.9s
# 29:	learn: 0.0223195	total: 2.08s	remaining: 11.8s
# 30:	learn: 0.0222929	total: 2.14s	remaining: 11.7s
# 31:	learn: 0.0222689	total: 2.19s	remaining: 11.5s
# 32:	learn: 0.0222220	total: 2.25s	remaining: 11.4s
# 33:	learn: 0.0221902	total: 2.31s	remaining: 11.3s
# 34:	learn: 0.0221698	total: 2.37s	remaining: 11.2s
# 35:	learn: 0.0221364	total: 2.43s	remaining: 11.1s
# 36:	learn: 0.0220873	total: 2.48s	remaining: 11s
# 37:	learn: 0.0220610	total: 2.54s	remaining: 10.9s
# 38:	learn: 0.0220373	total: 2.6s	remaining: 10.7s
# 39:	learn: 0.0220071	total: 2.66s	remaining: 10.6s
# 40:	learn: 0.0219821	total: 2.71s	remaining: 10.5s
# 41:	learn: 0.0219505	total: 2.77s	remaining: 10.4s
# 42:	learn: 0.0219224	total: 2.83s	remaining: 10.3s
# 43:	learn: 0.0218941	total: 2.88s	remaining: 10.2s
# 44:	learn: 0.0218751	total: 2.94s	remaining: 10.1s
# 45:	learn: 0.0218433	total: 2.99s	remaining: 10s
# 46:	learn: 0.0218154	total: 3.05s	remaining: 9.93s
# 47:	learn: 0.0217910	total: 3.1s	remaining: 9.83s
# 48:	learn: 0.0217804	total: 3.16s	remaining: 9.74s
# 49:	learn: 0.0217651	total: 3.22s	remaining: 9.65s
# 50:	learn: 0.0217467	total: 3.27s	remaining: 9.56s
# 51:	learn: 0.0217276	total: 3.33s	remaining: 9.47s
# 52:	learn: 0.0217017	total: 3.38s	remaining: 9.39s
# 53:	learn: 0.0216812	total: 3.44s	remaining: 9.3s
# 54:	learn: 0.0216677	total: 3.5s	remaining: 9.22s
# 55:	learn: 0.0216495	total: 3.55s	remaining: 9.14s
# 56:	learn: 0.0216026	total: 3.61s	remaining: 9.06s
# 57:	learn: 0.0215895	total: 3.67s	remaining: 8.98s
# 58:	learn: 0.0215779	total: 3.72s	remaining: 8.89s
# 59:	learn: 0.0215651	total: 3.78s	remaining: 8.81s
# 60:	learn: 0.0215568	total: 3.83s	remaining: 8.73s
# 61:	learn: 0.0215417	total: 3.89s	remaining: 8.66s
# 62:	learn: 0.0215263	total: 3.94s	remaining: 8.58s
# 63:	learn: 0.0214904	total: 4s	remaining: 8.5s
# 64:	learn: 0.0214656	total: 4.06s	remaining: 8.43s
# 65:	learn: 0.0214426	total: 4.12s	remaining: 8.36s
# 66:	learn: 0.0214254	total: 4.18s	remaining: 8.3s
# 67:	learn: 0.0214066	total: 4.24s	remaining: 8.22s
# 68:	learn: 0.0213933	total: 4.29s	remaining: 8.15s
# 69:	learn: 0.0213818	total: 4.35s	remaining: 8.08s
# 70:	learn: 0.0213634	total: 4.41s	remaining: 8.01s
# 71:	learn: 0.0213511	total: 4.47s	remaining: 7.94s
# 72:	learn: 0.0213339	total: 4.53s	remaining: 7.87s
# 73:	learn: 0.0213255	total: 4.59s	remaining: 7.81s
# 74:	learn: 0.0212495	total: 4.64s	remaining: 7.74s
# 75:	learn: 0.0212026	total: 4.7s	remaining: 7.67s
# 76:	learn: 0.0211717	total: 4.76s	remaining: 7.6s
# 77:	learn: 0.0211398	total: 4.81s	remaining: 7.53s
# 78:	learn: 0.0211080	total: 4.87s	remaining: 7.46s
# 79:	learn: 0.0210994	total: 4.92s	remaining: 7.39s
# 80:	learn: 0.0210838	total: 4.98s	remaining: 7.32s
# 81:	learn: 0.0210693	total: 5.04s	remaining: 7.25s
# 82:	learn: 0.0210618	total: 5.09s	remaining: 7.18s
# 83:	learn: 0.0210507	total: 5.15s	remaining: 7.11s
# 84:	learn: 0.0210272	total: 5.21s	remaining: 7.04s
# 85:	learn: 0.0210182	total: 5.26s	remaining: 6.97s
# 86:	learn: 0.0210093	total: 5.32s	remaining: 6.9s
# 87:	learn: 0.0209939	total: 5.37s	remaining: 6.84s
# 88:	learn: 0.0209844	total: 5.43s	remaining: 6.77s
# 89:	learn: 0.0209696	total: 5.49s	remaining: 6.7s
# 90:	learn: 0.0209581	total: 5.54s	remaining: 6.63s
# 91:	learn: 0.0209498	total: 5.59s	remaining: 6.57s
# 92:	learn: 0.0209377	total: 5.65s	remaining: 6.5s
# 93:	learn: 0.0209286	total: 5.71s	remaining: 6.44s
# 94:	learn: 0.0209216	total: 5.76s	remaining: 6.37s
# 95:	learn: 0.0209154	total: 5.82s	remaining: 6.3s
# 96:	learn: 0.0209062	total: 5.87s	remaining: 6.24s
# 97:	learn: 0.0208980	total: 5.93s	remaining: 6.17s
# 98:	learn: 0.0208830	total: 5.98s	remaining: 6.11s
# 99:	learn: 0.0208749	total: 6.04s	remaining: 6.04s
# 100:	learn: 0.0208603	total: 6.09s	remaining: 5.97s
# 101:	learn: 0.0208526	total: 6.16s	remaining: 5.92s
# 102:	learn: 0.0208414	total: 6.21s	remaining: 5.85s
# 103:	learn: 0.0208177	total: 6.27s	remaining: 5.79s
# 104:	learn: 0.0208126	total: 6.32s	remaining: 5.72s
# 105:	learn: 0.0207973	total: 6.38s	remaining: 5.66s
# 106:	learn: 0.0207914	total: 6.43s	remaining: 5.59s
# 107:	learn: 0.0207811	total: 6.49s	remaining: 5.53s
# 108:	learn: 0.0207745	total: 6.55s	remaining: 5.47s
# 109:	learn: 0.0207672	total: 6.61s	remaining: 5.41s
# 110:	learn: 0.0207606	total: 6.67s	remaining: 5.34s
# 111:	learn: 0.0207584	total: 6.72s	remaining: 5.28s
# 112:	learn: 0.0207524	total: 6.78s	remaining: 5.22s
# 113:	learn: 0.0207486	total: 6.83s	remaining: 5.16s
# 114:	learn: 0.0207350	total: 6.89s	remaining: 5.09s
# 115:	learn: 0.0207301	total: 6.94s	remaining: 5.03s
# 116:	learn: 0.0207195	total: 7s	remaining: 4.96s
# 117:	learn: 0.0207111	total: 7.05s	remaining: 4.9s
# 118:	learn: 0.0207043	total: 7.11s	remaining: 4.84s
# 119:	learn: 0.0207004	total: 7.17s	remaining: 4.78s
# 120:	learn: 0.0206940	total: 7.23s	remaining: 4.72s
# 121:	learn: 0.0206880	total: 7.29s	remaining: 4.66s
# 122:	learn: 0.0206841	total: 7.34s	remaining: 4.6s
# 123:	learn: 0.0206679	total: 7.4s	remaining: 4.53s
# 124:	learn: 0.0206609	total: 7.45s	remaining: 4.47s
# 125:	learn: 0.0206554	total: 7.51s	remaining: 4.41s
# 126:	learn: 0.0206465	total: 7.57s	remaining: 4.35s
# 127:	learn: 0.0206438	total: 7.62s	remaining: 4.29s
# 128:	learn: 0.0206395	total: 7.68s	remaining: 4.22s
# 129:	learn: 0.0206247	total: 7.73s	remaining: 4.16s
# 130:	learn: 0.0205978	total: 7.79s	remaining: 4.1s
# 131:	learn: 0.0205925	total: 7.86s	remaining: 4.05s
# 132:	learn: 0.0205844	total: 7.92s	remaining: 3.99s
# 133:	learn: 0.0205760	total: 7.97s	remaining: 3.92s
# 134:	learn: 0.0205707	total: 8.03s	remaining: 3.86s
# 135:	learn: 0.0205681	total: 8.08s	remaining: 3.8s
# 136:	learn: 0.0205658	total: 8.13s	remaining: 3.74s
# 137:	learn: 0.0205609	total: 8.19s	remaining: 3.68s
# 138:	learn: 0.0205540	total: 8.24s	remaining: 3.62s
# 139:	learn: 0.0205510	total: 8.3s	remaining: 3.56s
# 140:	learn: 0.0205492	total: 8.35s	remaining: 3.49s
# 141:	learn: 0.0205438	total: 8.41s	remaining: 3.43s
# 142:	learn: 0.0205420	total: 8.46s	remaining: 3.37s
# 143:	learn: 0.0205396	total: 8.52s	remaining: 3.31s
# 144:	learn: 0.0205344	total: 8.57s	remaining: 3.25s
# 145:	learn: 0.0205293	total: 8.63s	remaining: 3.19s
# 146:	learn: 0.0205276	total: 8.69s	remaining: 3.13s
# 147:	learn: 0.0205256	total: 8.74s	remaining: 3.07s
# 148:	learn: 0.0205244	total: 8.81s	remaining: 3.01s
# 149:	learn: 0.0205190	total: 8.86s	remaining: 2.95s
# 150:	learn: 0.0205139	total: 8.92s	remaining: 2.9s
# 151:	learn: 0.0205117	total: 8.98s	remaining: 2.83s
# 152:	learn: 0.0205097	total: 9.04s	remaining: 2.78s
# 153:	learn: 0.0205062	total: 9.09s	remaining: 2.72s
# 154:	learn: 0.0205046	total: 9.15s	remaining: 2.66s
# 155:	learn: 0.0205006	total: 9.21s	remaining: 2.6s
# 156:	learn: 0.0204982	total: 9.27s	remaining: 2.54s
# 157:	learn: 0.0204980	total: 9.33s	remaining: 2.48s
# 158:	learn: 0.0204901	total: 9.39s	remaining: 2.42s
# 159:	learn: 0.0204863	total: 9.45s	remaining: 2.36s
# 160:	learn: 0.0204842	total: 9.51s	remaining: 2.3s
# 161:	learn: 0.0204814	total: 9.57s	remaining: 2.24s
# 162:	learn: 0.0204808	total: 9.62s	remaining: 2.18s
# 163:	learn: 0.0204745	total: 9.67s	remaining: 2.12s
# 164:	learn: 0.0204703	total: 9.73s	remaining: 2.06s
# 165:	learn: 0.0204683	total: 9.79s	remaining: 2s
# 166:	learn: 0.0204658	total: 9.84s	remaining: 1.94s
# 167:	learn: 0.0204639	total: 9.89s	remaining: 1.88s
# 168:	learn: 0.0204625	total: 9.95s	remaining: 1.82s
# 169:	learn: 0.0204611	total: 10s	remaining: 1.76s
# 170:	learn: 0.0204592	total: 10.1s	remaining: 1.71s
# 171:	learn: 0.0204579	total: 10.1s	remaining: 1.65s
# 172:	learn: 0.0204568	total: 10.2s	remaining: 1.59s
# 173:	learn: 0.0204556	total: 10.2s	remaining: 1.53s
# 174:	learn: 0.0204548	total: 10.3s	remaining: 1.47s
# 175:	learn: 0.0204541	total: 10.3s	remaining: 1.41s
# 176:	learn: 0.0204528	total: 10.4s	remaining: 1.35s
# 177:	learn: 0.0204187	total: 10.5s	remaining: 1.29s
# 178:	learn: 0.0204173	total: 10.5s	remaining: 1.23s
# 179:	learn: 0.0204151	total: 10.6s	remaining: 1.17s
# 180:	learn: 0.0204135	total: 10.6s	remaining: 1.11s
# 181:	learn: 0.0204127	total: 10.7s	remaining: 1.06s
# 182:	learn: 0.0204110	total: 10.7s	remaining: 998ms
# 183:	learn: 0.0204100	total: 10.8s	remaining: 939ms
# 184:	learn: 0.0204092	total: 10.8s	remaining: 880ms
# 185:	learn: 0.0204075	total: 10.9s	remaining: 821ms
# 186:	learn: 0.0204043	total: 11s	remaining: 763ms
# 187:	learn: 0.0204030	total: 11s	remaining: 705ms
# 188:	learn: 0.0203982	total: 11.1s	remaining: 646ms
# 189:	learn: 0.0203927	total: 11.2s	remaining: 588ms
# 190:	learn: 0.0203845	total: 11.2s	remaining: 529ms
# 191:	learn: 0.0203805	total: 11.3s	remaining: 470ms
# 192:	learn: 0.0203780	total: 11.3s	remaining: 411ms
# 193:	learn: 0.0203732	total: 11.4s	remaining: 352ms
# 194:	learn: 0.0203723	total: 11.5s	remaining: 294ms
# 195:	learn: 0.0203639	total: 11.5s	remaining: 235ms
# 196:	learn: 0.0203612	total: 11.6s	remaining: 176ms
# 197:	learn: 0.0203597	total: 11.6s	remaining: 117ms
# 198:	learn: 0.0203560	total: 11.7s	remaining: 58.6ms
# 199:	learn: 0.0203553	total: 11.7s	remaining: 0us
# Training accuracy: 64.13647882343237 %
# Validation accuracy: 63.441715645009985 %
# CatBoost Model Mean Absolute Percent Error: 0.020379972386191773
# CPU times: user 31.2 s, sys: 1.86 s, total: 33 s
# Wall time: 12.7 s

# %% [markdown]
# **EXTRA TREES REGRESSOR**

# %%
# %%time
etr_model = ExtraTreesRegressor(n_estimators=200, max_depth=12, random_state=42)
etr_model.fit(X_train, y_train)
etr_pred = etr_model.predict(X_test)

etr_train_acc = (etr_model.score(X_train, y_train))*100
etr_val_acc = (etr_model.score(X_test, y_test))*100
mape_etr = mean_absolute_percentage_error(y_test, cat_pred)

print(f"Training accuracy: {etr_train_acc} %")
print(f"Validation accuracy: {etr_val_acc} %")
print(f"CatBoost Model Mean Absolute Percent Error: {mape_etr}")
# Out:
# Training accuracy: 68.18454572542029 %
# Validation accuracy: 67.47624629441917 %
# CatBoost Model Mean Absolute Percent Error: 0.020379972386191773
# CPU times: user 2min 58s, sys: 845 ms, total: 2min 59s
# Wall time: 3min 1s

# %% [markdown]
# **BASE MODEL COMPARISON**

# %%
models = pd.DataFrame(
    {
    'Model Name': ['Linear','Random Forest','LightGBM','Lasso','Ridge','XGBoost','CatBoost', 'Extra Trees'],
    'Training Accuracy' : [lr_train_acc,rf_train_acc,lgb_train_acc,ls_train_acc,rg_train_acc, xg_train_acc, cat_train_acc, etr_train_acc],
    'Validation Accuracy' : [lr_val_acc, rf_val_acc,lgb_val_acc,ls_val_acc,rg_val_acc, xg_val_acc, cat_val_acc, etr_val_acc],
    'MAPE Score' : [mape_lr, mape_rf, mape_lgb, mape_ls,mape_rg, mape_xg,mape_cat, mape_etr]
    }
)

models.sort_values(by = ['MAPE Score'],ascending = True)
# Out:
#       Model Name  Training Accuracy  Validation Accuracy  MAPE Score
# 1  Random Forest          97.736905            83.653714    0.013641
# 5        XGBoost          92.487241            81.758424    0.015938
# 2       LightGBM          80.797600            78.603518    0.017745
# 6       CatBoost          64.136479            63.441716    0.020380
# 7    Extra Trees          68.184546            67.476246    0.020380
# 0         Linear          41.076121            41.254795    0.029450
# 4          Ridge          40.584315            40.747181    0.029602
# 3          Lasso          13.006683            12.956587    0.037757

# %% [markdown]
# # **PREDICTION**

# %% [markdown]
# **Predict using Base Model with the lowest MAPE score - Random Forest Regressor**

# %%
test.head()
# Out:
#    active_power_calculated_by_converter  active_power_raw  \
# 0                             -0.358164         -0.845516
# 1                              0.168609          0.192505
# 2                              0.162899          0.178816
# 3                              0.099447          0.032449
# 4                              0.258382          0.392340
#
#    ambient_temperature  generator_speed  generator_winding_temp_max  \
# 0             1.284113        -0.284848                   -0.258544
# 1            -1.889565         0.059108                   -0.904580
# 2             0.531272         0.052386                    0.072237
# 3             0.353109        -0.010172                   -0.437882
# 4             0.769846         0.139859                    0.719692
#
#    grid_power10min_average  nc1_inside_temp  nacelle_temp  \
# 0                 0.029225         3.062313      2.897717
# 1                 0.201000        -1.015945     -2.313470
# 2                 0.182062         1.619690      1.044187
# 3                 0.109681        -0.476413     -0.072102
# 4                 0.264371         0.115795     -0.149438
#
#    reactice_power_calculated_by_converter  reactive_power  wind_direction_raw  \
# 0                               -0.395739       -0.689105            0.097655
# 1                                0.208913        0.213674           -0.922848
# 2                                0.203772        0.212288            0.410800
# 3                                0.202880        0.203995            0.232288
# 4                                0.259997        0.261404            0.537062
#
#    wind_speed_raw  wind_speed_turbulence  turbine_id
# 0       -2.515149              -0.369523           9
# 1        0.222668              -0.369523          13
# 2        0.231956              -0.369523           9
# 3       -0.489671              -0.369523           5
# 4        0.808729              -0.369523          11

# %%
#test = test.drop(['active_power_calculated_by_converter','active_power_raw', 'reactive_power', 'reactice_power_calculated_by_converter'], axis=1)
test_pred = rf_model.predict(test)
submission = pd.DataFrame()
submission['Target'] = test_pred
submission['Target'].head()
submission['Target'].to_csv('./ReNew_Participants_Data/1009_my_submission.csv', index=False)

# %%
submission.head()
# Out:
#       Target
# 0  50.149284
# 1  40.872206
# 2  48.536627
# 3  45.899249
# 4  48.141144

# %% [markdown]
# # **HYPERPARAMETER TUNING TO IMPROVE MAPE METRIC**

# %% [markdown]
# **Random Forest with Hyperopt**

# %%
from hyperopt import fmin, hp, tpe, Trials, space_eval, STATUS_OK, SparkTrials

def objective(search_space):
    model = RandomForestRegressor(n_estimators = search_space["n_estimators"],
                               max_depth = int(search_space["max_depth"]), 
                              n_jobs = -1,
                              random_state = 42)
                              
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    MAPE = mean_absolute_percentage_error(y_test, y_pred)
    return {"loss": MAPE, "status": STATUS_OK}

# %%
search_space = {"max_depth": hp.quniform("max_depth", 3, 18, 1),
                "n_estimators": hp.choice("n_estimators",range(100,300,10))
               }

# %% [markdown]
# trials = Trials()
#
# best_params = fmin(fn = objective,
#                    space = search_space,
#                    algo = tpe.suggest,
#                    max_evals = 100,
#                    trials = trials)

# %%
best_params
# Out:
# {'max_depth': 18.0, 'n_estimators': 19}

# %%
# Running RF with best params
#%%time
rf_model_opt = RandomForestRegressor(max_depth=18, n_estimators=19,random_state=42)
rf_model_opt.fit(X_train, y_train)
rf_pred_opt = rf_model_opt.predict(X_test)

rfopt_train_acc = (rf_model_opt.score(X_train, y_train))*100
rfopt_val_acc = (rf_model_opt.score(X_test, y_test))*100
mape_rfopt = mean_absolute_percentage_error(y_test, rf_pred_opt)

print(f"Training accuracy: {rfopt_train_acc} %")
print(f"Validation accuracy: {rfopt_val_acc} %")
print(f"Random Forest Model Mean Absolute Percent Error: {mape_rfopt}")
# Out:
# Training accuracy: 88.7505148450023 %
# Validation accuracy: 80.41791499658844 %
# Random Forest Model Mean Absolute Percent Error: 0.015757447220615037

# %% [markdown]
# The Hyperopt optimization for Random Forest did not make it any better - instead, we see the MAPE score for the optimized model is slightly higher than the base model.
#
# We will try tuning the other 2 models after Random Forest - XGBoost and LightGBM.

# %% [markdown]
# **Hyperopt Tuning XGBoost**

# %%
def objective(search_space):
    xgbmodel = xgb.XGBRegressor(n_estimators = search_space["n_estimators"],
                              max_depth = int(search_space["max_depth"]),
                              gamma = search_space["gamma"],
                             learning_rate = search_space["learning_rate"],
                              reg_alpha = int(search_space["reg_alpha"]),
                              min_child_weight = search_space["min_child_weight"],
                              colsample_bytree = search_space["colsample_bytree"],
                              n_jobs = -1,
                              random_state = 42)
    xgbmodel.fit(X_train, y_train)
    xgb_pred = xgbmodel.predict(X_test)
    MAPE = mean_absolute_percentage_error(y_test, xgb_pred)
    return {"loss": MAPE, "status": STATUS_OK}

# %%
search_space = {"max_depth": hp.quniform("max_depth", 3, 18, 1),
                "gamma": hp.uniform("gamma", 1, 9),
                "reg_alpha" : hp.quniform("reg_alpha", 40, 180, 1),
                "reg_lambda": hp.uniform("reg_lambda", 0, 1),
                "colsample_bytree": hp.uniform("colsample_bytree", 0.5, 1),
                "min_child_weight": hp.quniform("min_child_weight", 0, 10, 1),
                "n_estimators": hp.choice("n_estimators",range(100,300,10)),
                "learning_rate": hp.choice("learning_rate",[0.01,0.02,.1,.2,.03])
               }

# %%
trials = Trials()

best_params = fmin(fn = objective,
                   space = search_space,
                   algo = tpe.suggest,
                   max_evals = 100,
                   trials = trials)
# Out:
# 100%|██████████| 100/100 [8:57:14<00:00, 322.35s/trial, best loss: 0.015691702851281696]

# %%
best_params
# Out:
# {'colsample_bytree': 0.655133758547989,
#  'gamma': 1.9134779479411455,
#  'learning_rate': 3,
#  'max_depth': 17.0,
#  'min_child_weight': 2.0,
#  'n_estimators': 14,
#  'reg_alpha': 48.0,
#  'reg_lambda': 0.4509727735902072}

# %%
# %%time
# XG Boost Regressor
XGB_modelopt = XGBRegressor(booster='gbtree', n_estimators=14, max_depth=17, random_state=42, colsample_bytree = 0.655133758547989,gamma = 1.9134779479411455,
                        learning_rate = 3, min_child_weight = 2,reg_alpha = 48, reg_lambda = 0.4509727735902072)
XGB_modelopt.fit(X_train, y_train)
XGBopt_pred = XGB_modelopt.predict(X_test)

xgopt_train_acc = (XGB_modelopt.score(X_train, y_train))*100
xgopt_val_acc = (XGB_modelopt.score(X_test, y_test))*100
mape_xgopt = mean_absolute_percentage_error(y_test, XGBopt_pred)

print(f"Training accuracy: {xgopt_train_acc} %")
print(f"Validation accuracy: {xgopt_val_acc} %")
print(f"XGBoost Model Mean Absolute Percent Error: {mape_xgopt}")
# Out:
# Training accuracy: -8204103284814.382 %
# Validation accuracy: -8305473402729.211 %
# XGBoost Model Mean Absolute Percent Error: 16245.745452738598
# CPU times: user 48.7 s, sys: 4.36 s, total: 53 s
# Wall time: 7.55 s

# %% [markdown]
# **Hyperopt Tuning LightGBM**

# %%
def objective(search_space):
    lgb_model = LGBMRegressor(n_estimators = search_space["n_estimators"],
                              max_depth = int(search_space["max_depth"]),
                             learning_rate = search_space["learning_rate"],
                              reg_alpha = int(search_space["reg_alpha"]),
                              min_child_weight = search_space["min_child_weight"],
                              colsample_bytree = search_space["colsample_bytree"],
                              n_jobs = -1,
                              random_state = 42)
    lgb_model.fit(X_train, y_train)
    lgb_pred = lgb_model.predict(X_test)
    lgb_mape = mean_absolute_percentage_error(y_test, lgb_pred)
    return {"loss": lgb_mape, "status": STATUS_OK}

# %%
search_space = {"max_depth": hp.quniform("max_depth", 3, 18, 1),
                "reg_alpha" : hp.quniform("reg_alpha", 40, 180, 1),
                "reg_lambda": hp.uniform("reg_lambda", 0, 1),
                "colsample_bytree": hp.uniform("colsample_bytree", 0.5, 1),
                "min_child_weight": hp.quniform("min_child_weight", 0, 10, 1),
                "n_estimators": hp.choice("n_estimators",range(100,300,10)),
                "learning_rate": hp.choice("learning_rate",[0.01,0.02,.1,.2,.03])
               }

# %%
trials = Trials()

best_params = fmin(fn = objective,
                   space = search_space,
                   algo = tpe.suggest,
                   max_evals = 100,
                   trials = trials)
# Out:
# 100%|██████████| 100/100 [06:15<00:00,  3.75s/trial, best loss: 0.018591713398490303]

# %%
best_params
# Out:
# {'colsample_bytree': 0.9967264373234868,
#  'learning_rate': 3,
#  'max_depth': 16.0,
#  'min_child_weight': 5.0,
#  'n_estimators': 17,
#  'reg_alpha': 47.0,
#  'reg_lambda': 0.7529823620665808}

# %% [markdown]
# **Hyperopt Tuning CATBoost**

# %%
def objective(trial):
    train_x, test_x, train_y, test_y = train_test_split(X,y,test_size=0.15,random_state=42)
    
    param = {
        'eval_metric': 'MAPE', 
        'n_estimators': trial.suggest_int('n_estimators',500,20000),
        'learning_rate': trial.suggest_float('learning_rate', 0.001,0.2 ),
        'depth' : trial.suggest_int('depth', 9, 15),
        'l2_leaf_reg' : trial.suggest_loguniform('l2_leaf_reg', 1e-3, 10.0),
        'random_strength' : trial.suggest_float('random_strength',0.2,0.8),
        'bagging_temperature':trial.suggest_float('bagging_temperature',0.03,0.8),
        'border_count': 254,
        'od_type' : 'Iter',
        'use_best_model': True,
        #'task_type' : 'GPU',
        'random_state' : 42,
        'logging_level' : 'Silent'
    }
                                                        
    cb_model = CatBoostRegressor(**param)  
    cb_model.set_params(early_stopping_rounds=100)
    cb_model.fit(train_x, train_y, eval_set=[(test_x, test_y)], verbose=1000)
    cb_preds = cb_model.predict(test_x)
    mape = mean_absolute_percentage_error(test_y, cb_preds)
    return mape

# %%
import optuna
study = optuna.create_study(direction='minimize')
study.optimize(objective,show_progress_bar=True,timeout=14400)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2022-09-09 23:24:22,509] A new study created in memory with name: no-name-d5727523-a19d-40be-9ba5-1d87d8a10edc
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/optuna/progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
# 0it [00:00, ?it/s]
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# [I 2022-09-09 23:41:07,723] Trial 0 finished with value: 0.01746034526582055 and parameters: {'n_estimators': 13638, 'learning_rate': 0.13449787426892923, 'depth': 12, 'l2_leaf_reg': 0.00881553261951302, 'random_strength': 0.4519677925521923, 'bagging_temperature': 0.5729108654056353}. Best is trial 0 with value: 0.01746034526582055.
# [I 2022-09-09 23:44:11,504] Trial 1 finished with value: 0.018560888266546994 and parameters: {'n_estimators': 4417, 'learning_rate': 0.17652272144150036, 'depth': 9, 'l2_leaf_reg': 3.896710398866506, 'random_strength': 0.7031013363011336, 'bagging_temperature': 0.7269096431442378}. Best is trial 0 with value: 0.01746034526582055.
# [I 2022-09-09 23:57:19,860] Trial 2 finished with value: 0.017581664059260118 and parameters: {'n_estimators': 8816, 'learning_rate': 0.17636114598543803, 'depth': 12, 'l2_leaf_reg': 3.4514362074294787, 'random_strength': 0.7459075205458268, 'bagging_temperature': 0.7965128234788169}. Best is trial 0 with value: 0.01746034526582055.
# [I 2022-09-10 02:52:16,356] Trial 3 finished with value: 0.01740916365295084 and parameters: {'n_estimators': 10832, 'learning_rate': 0.13690034683421717, 'depth': 14, 'l2_leaf_reg': 0.8454355884909517, 'random_strength': 0.6378713289554633, 'bagging_temperature': 0.416848428777717}. Best is trial 3 with value: 0.01740916365295084.
# [I 2022-09-10 02:55:17,599] Trial 4 finished with value: 0.019097666746208164 and parameters: {'n_estimators': 3422, 'learning_rate': 0.0673441049121513, 'depth': 10, 'l2_leaf_reg': 0.5838556763789673, 'random_strength': 0.22666925334932805, 'bagging_temperature': 0.03086902447803526}. Best is trial 3 with value: 0.01740916365295084.
# [I 2022-09-10 04:55:16,511] Trial 5 finished with value: 0.01795002206929496 and parameters: {'n_estimators': 6456, 'learning_rate': 0.1984004209815075, 'depth': 15, 'l2_leaf_reg': 0.22855485445589585, 'random_strength': 0.630336470327431, 'bagging_temperature': 0.7924174812343047}. Best is trial 3 with value: 0.01740916365295084.
# Number of finished trials: 6
# Best trial: {'n_estimators': 10832, 'learning_rate': 0.13690034683421717, 'depth': 14, 'l2_leaf_reg': 0.8454355884909517, 'random_strength': 0.6378713289554633, 'bagging_temperature': 0.416848428777717}

# %%
print('Best trial:', study.best_trial.params)
# Out:
# Best trial: {'n_estimators': 10832, 'learning_rate': 0.13690034683421717, 'depth': 14, 'l2_leaf_reg': 0.8454355884909517, 'random_strength': 0.6378713289554633, 'bagging_temperature': 0.416848428777717}

# %%
params = {'n_estimators': 10832, 'learning_rate': 0.13690034683421717, 'depth': 14, 'l2_leaf_reg': 0.8454355884909517, 'random_strength': 0.6378713289554633, 'bagging_temperature': 0.416848428777717}

# %%
test.head()
# Out:
#    ambient_temperature  generator_speed  generator_winding_temp_max  \
# 0             2.048489        -2.497042                   -0.305111
# 1            -1.566007         0.144343                   -0.922176
# 2             0.390471         0.053440                    0.025699
# 3             0.115958        -0.688208                   -0.480182
# 4             0.818413         1.446851                    0.704211
#
#    grid_power10min_average  nc1_inside_temp  nacelle_temp  wind_direction_raw  \
# 0                -1.009614         4.486108      4.576369           -0.389183
# 1                 0.248735        -1.094694     -2.018279           -1.373470
# 2                 0.039673         1.971111      1.165867            0.255665
# 3                -0.569982        -0.588290     -0.204204           -0.143695
# 4                 1.169394         0.031213     -0.285226            0.601470
#
#    wind_speed_raw  wind_speed_turbulence
# 0       -2.254006               0.698795
# 1        0.133691              -0.178899
# 2        0.146219              -0.316702
# 3       -0.716170              -0.633185
# 4        1.009043              -0.104702

# %%
cat_model_opt = CatBoostRegressor(**params)
cat_model_opt.fit(X, y)
catopt_pred = cat_model_opt.predict(test)

#submission_opt = pd.DataFrame()
#submission_opt['Target'] = catopt_pred 

catopt_train_acc = (cat_model_opt.score(X_train, y_train))*100
catopt_val_acc = (cat_model_opt.score(X_test, y_test))*100
mape_catopt = mean_absolute_percentage_error(y_test, catopt_pred)

print(f"Training accuracy: {catopt_train_acc} %")
print(f"Validation accuracy: {catopt_val_acc} %")
print(f"CatBoost Model Mean Absolute Percent Error: {mape_catopt}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/rishimadhav/Desktop/Github/ReNew Power Hackathon/ReNew_hackathon_1009.ipynb Cell 99 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/rishimadhav/Desktop/Github/ReNew%20Power%20Hackathon/ReNew_hackathon_1009.ipynb#Y136sZmlsZQ%3D%3D?line=0'>1</a> cat_model_opt = CatBoostRegressor(**params)
#       <a href='vscode-notebook-cell:/Users/rishimadhav/Desktop/Github/ReNew%20Power%20Hackathon/ReNew_hackathon_1009.ipynb#Y136sZmlsZQ%3D%3D?line=1'>2</a> cat_model_opt.fit(X, y)
#       <a href='vscode-notebook-cell:/Users/rishimadhav/Desktop/Github/ReNew%20Power%20Hackathon/ReNew_hackathon_1009.ipynb#Y136sZmlsZQ%3D%3D?line=2'>3</a> catopt_pred = cat_model_opt.predict(test)
#
# NameError: name 'params' is not defined

# %%
submission_opt.head()
# Out:
#       Target
# 0  48.963587
# 1  40.538213
# 2  48.193484
# 3  45.963646
# 4  44.706290

# %% [markdown]
# **MODELS COMPARISON AFTER HYPEROPT TUNING**

# %%
models = pd.DataFrame(
    {
    'Model Name': ['Random Forest','LightGBM','XGBoost','CatBoost', 'Extra Trees'],
    'MAPE Score' : mape_rf, mape_lgb, mape_ls,mape_rg, mape_xg,mape_cat, mape_etr]
    }
)

models.sort_values(by = ['MAPE Score'],ascending = True)
